# %% [markdown]
# <a href="https://colab.research.google.com/github/leeilgyu/pyhton/blob/main/11_9_%EA%B3%BC%EC%A0%9C_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np

X = np.linspace(0,2,200)
Y = X**2 + np.sin(3*X+7)

plt.plot(X,Y)
plt.show()
